# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO, SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

env = gym.make('CartPole-v1',render_mode="human")
env.reset()

# env = make_vec_env('CartPole-v1', n_envs=16)
# Out:
# (array([ 0.03779164, -0.03264511, -0.01365047, -0.00230172], dtype=float32),
#  {})

# %%
model = SAC('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model = SAC('MlpPolicy', env, verbose=1)
#
# File ~/pytorch_learning/venv/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:120, in SAC.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, ent_coef, target_update_interval, target_entropy, use_sde, sde_sample_freq, use_sde_at_warmup, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#      90 def __init__(
#      91     self,
#      92     policy: Union[str, Type[SACPolicy]],
#    (...)
#     118     _init_setup_model: bool = True,
#     119 ):
# --> 120     super().__init__(
#     121         policy,
#     122         env,
#     123         learning_rate,
#     124         buffer_size,
#     125         learning_starts,
#     126         batch_size,
#     127         tau,
#     128         gamma,
#     129         train_freq,
#     130         gradient_steps,
#     131         action_noise,
#     132         replay_buffer_class=replay_buffer_class,
#     133         replay_buffer_kwargs=replay_buffer_kwargs,
#     134         policy_kwargs=policy_kwargs,
#     135         stats_window_size=stats_window_size,
#     136         tensorboard_log=tensorboard_log,
#     137         verbose=verbose,
#     138         device=device,
#     139         seed=seed,
#     140         use_sde=use_sde,
#     141         sde_sample_freq=sde_sample_freq,
#     142         use_sde_at_warmup=use_sde_at_warmup,
#     143         optimize_memory_usage=optimize_memory_usage,
#     144         supported_action_spaces=(spaces.Box,),
#     145         support_multi_env=True,
#     146     )
#     148     self.target_entropy = target_entropy
#     149     self.log_ent_coef = None  # type: Optional[th.Tensor]
#
# File ~/pytorch_learning/venv/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:110, in OffPolicyAlgorithm.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#      80 def __init__(
#      81     self,
#      82     policy: Union[str, Type[BasePolicy]],
#    (...)
#     108     supported_action_spaces: Optional[Tuple[Type[spaces.Space], ...]] = None,
#     109 ):
# --> 110     super().__init__(
#     111         policy=policy,
#     112         env=env,
#     113         learning_rate=learning_rate,
#     114         policy_kwargs=policy_kwargs,
#     115         stats_window_size=stats_window_size,
#     116         tensorboard_log=tensorboard_log,
#     117         verbose=verbose,
#     118         device=device,
#     119         support_multi_env=support_multi_env,
#     120         monitor_wrapper=monitor_wrapper,
#     121         seed=seed,
#     122         use_sde=use_sde,
#     123         sde_sample_freq=sde_sample_freq,
#     124         supported_action_spaces=supported_action_spaces,
#     125     )
#     126     self.buffer_size = buffer_size
#     127     self.batch_size = batch_size
#
# File ~/pytorch_learning/venv/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:180, in BaseAlgorithm.__init__(self, policy, env, learning_rate, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     177 self._vec_normalize_env = unwrap_vec_normalize(env)
#     179 if supported_action_spaces is not None:
# --> 180     assert isinstance(self.action_space, supported_action_spaces), (
#     181         f"The algorithm only supports {supported_action_spaces} as action spaces "
#     182         f"but {self.action_space} was provided"
#     183     )
#     185 if not support_multi_env and self.n_envs > 1:
#     186     raise ValueError(
#     187         "Error: the model does not support multiple envs; it requires " "a single vectorized environment."
#     188     )
#
# AssertionError: The algorithm only supports (<class 'gymnasium.spaces.box.Box'>,) as action spaces but Discrete(2) was provided

# %%
model.learn(total_timesteps=1000000)
model_name = "ppo_cartpole"
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 22.3     |
# | time/              |          |
# |    fps             | 2159     |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | 39.7        |
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 2           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016657505 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | -0.000973   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.35        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.7        |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 3           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020545587 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 28          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 885         |
# |    iterations           | 4           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.013339352 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 38.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | 285         |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 5           |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.013904242 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.77        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 27.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 373         |
# |    ep_rew_mean          | 373         |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 6           |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.015900765 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 447         |
# |    ep_rew_mean          | 447         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 7           |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.008914689 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 5.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | 484         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 8           |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.007918404 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 9           |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.009311391 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.453      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.2         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 1.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 10          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.003832324 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.424       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 0.589       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 11           |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0034306904 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.382        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 0.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 12           |
# |    time_elapsed         | 540          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0023112858 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.434       |
# |    explained_variance   | 0.0755       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0411       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000606    |
# |    value_loss           | 0.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 13           |
# |    time_elapsed         | 588          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0021030186 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.0192       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.019        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000575    |
# |    value_loss           | 0.199        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 14           |
# |    time_elapsed         | 621          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0015235171 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | -0.00687     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0477       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.000139     |
# |    value_loss           | 0.137        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 15           |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0025428198 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | 0.00118      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0371       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000257    |
# |    value_loss           | 0.0897       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 16          |
# |    time_elapsed         | 700         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.002979883 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.00776     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0089      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000133   |
# |    value_loss           | 0.062       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 17           |
# |    time_elapsed         | 731          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0019994983 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.419       |
# |    explained_variance   | 0.0369       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0372       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000352    |
# |    value_loss           | 0.0423       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 18           |
# |    time_elapsed         | 815          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0041832305 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00698      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 0.0287       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 19           |
# |    time_elapsed         | 869          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0030794959 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00147     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00092     |
# |    value_loss           | 0.0199       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 20           |
# |    time_elapsed         | 935          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0026481268 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | 0.0359       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0028       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000636    |
# |    value_loss           | 0.0137       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 21           |
# |    time_elapsed         | 1012         |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0033822348 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.429       |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00248      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00094     |
# |    value_loss           | 0.00934      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 676          |
# |    iterations           | 22           |
# |    time_elapsed         | 1066         |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0023712208 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | -0.00348     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0049       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 0.00635      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 23           |
# |    time_elapsed         | 1140         |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0038299086 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | -0.00628     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0125       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000893    |
# |    value_loss           | 0.00452      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 656         |
# |    iterations           | 24          |
# |    time_elapsed         | 1197        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.002394402 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | 0.0163      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000405   |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000663   |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 653          |
# |    iterations           | 25           |
# |    time_elapsed         | 1253         |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0020735855 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.0562       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00237      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 8.92e-05     |
# |    value_loss           | 0.00218      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 26           |
# |    time_elapsed         | 1310         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0029583923 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.0714       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00523     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000645    |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 27           |
# |    time_elapsed         | 1365         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0027711815 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.0624       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0036      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000409    |
# |    value_loss           | 0.00106      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 28          |
# |    time_elapsed         | 1422        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.002077185 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | 0.068       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00365     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000193   |
# |    value_loss           | 0.00076     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 29           |
# |    time_elapsed         | 1493         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0034952601 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0.0763       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000745     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000392    |
# |    value_loss           | 0.000524     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 30           |
# |    time_elapsed         | 1563         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0033668664 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.443       |
# |    explained_variance   | 0.0383       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000694     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000656    |
# |    value_loss           | 0.000377     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 31           |
# |    time_elapsed         | 1634         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0024740389 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.0477       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00775     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000481    |
# |    value_loss           | 0.000259     |
# ------------------------------------------

# %%
model.save(model_name)

# %%
import cv2

# %%
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(500):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
