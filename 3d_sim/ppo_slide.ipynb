# %%
import os

import gymnasium as gym
import panda_gym
import torch as th
from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C, PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor, FlattenExtractor
from huggingface_hub import notebook_login

# %%
env_id = "PandaSlide-v3"

# %%
env = make_vec_env(env_id, n_envs=16)
env = VecNormalize(env,norm_obs=True, norm_reward=True)
# Out:
# pybullet build time: Nov 28 2023 23:45:17
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %%
policy_ppo = {
    "net_arch":  [dict(pi=[512, 512,512], vf=[512, 512,512])],
    "activation_fn": th.nn.ReLU
}

# %%
model_ppo = PPO(
    policy="MultiInputPolicy",
    env=env,
    policy_kwargs=policy_ppo,
    verbose=1,
    learning_rate=1.5e-4,  # Adjusted learning rate
    n_steps=2048,  # Increased n_steps for more stable updates
    batch_size=2048,  # Appropriate batch size
    n_epochs=20,  
    gamma=0.98,
    gae_lambda=0.95,
    clip_range=0.2,  
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    tensorboard_log="./ppo" + env_id + "/",
)
# Out:
# Using cuda device
# /home/tomek/pytorch_learning/venv/lib/python3.10/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model_ppo.learn(10_000_000)
# Out:
# Logging to ./ppoPandaSlide-v3/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.7     |
# |    ep_rew_mean     | -49.7    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    fps             | 526      |
# |    iterations      | 1        |
# |    time_elapsed    | 62       |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.7        |
# |    ep_rew_mean          | -49.7       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 2           |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005682204 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.0558      |
# |    learning_rate        | 0.00015     |
# |    loss                 | 0.0525      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00791    |
# |    std                  | 1           |
# |    value_loss           | 0.284       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.9       |
# |    ep_rew_mean          | -49.9      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 522        |
# |    iterations           | 3          |
# |    time_elapsed         | 187        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00964101 |
# |    clip_fraction        | 0.0871     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0498    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0203    |
# |    std                  | 0.997      |
# |    value_loss           | 0.056      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 4           |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010802591 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0602     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.989       |
# |    value_loss           | 0.0391      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 5           |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.013103168 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0699     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0298     |
# |    std                  | 0.98        |
# |    value_loss           | 0.0295      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.7        |
# |    ep_rew_mean          | -49.7       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 6           |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016492676 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0837     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0355     |
# |    std                  | 0.969       |
# |    value_loss           | 0.0224      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 7           |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.017049376 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.087      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0368     |
# |    std                  | 0.958       |
# |    value_loss           | 0.019       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 8           |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.019362822 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0787     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0379     |
# |    std                  | 0.943       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.7        |
# |    ep_rew_mean          | -49.7       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 9           |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.021084435 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0899     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0369     |
# |    std                  | 0.926       |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 526         |
# |    iterations           | 10          |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.018853642 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0813     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0347     |
# |    std                  | 0.911       |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 529        |
# |    iterations           | 11         |
# |    time_elapsed         | 680        |
# |    total_timesteps      | 360448     |
# | train/                  |            |
# |    approx_kl            | 0.01863038 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.94      |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0842    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0338    |
# |    std                  | 0.895      |
# |    value_loss           | 0.00872    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.8        |
# |    ep_rew_mean          | -49.8       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 12          |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.019484153 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0852     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0336     |
# |    std                  | 0.879       |
# |    value_loss           | 0.00584     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.3        |
# |    ep_rew_mean          | -49.2       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 13          |
# |    time_elapsed         | 803         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.018672321 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.076      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.866       |
# |    value_loss           | 0.00626     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 14          |
# |    time_elapsed         | 861         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.017426679 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0692     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 0.856       |
# |    value_loss           | 0.00955     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 15          |
# |    time_elapsed         | 919         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.020071732 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0825     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 0.844       |
# |    value_loss           | 0.00479     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 16          |
# |    time_elapsed         | 980         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.019477084 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0691     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0301     |
# |    std                  | 0.832       |
# |    value_loss           | 0.00499     |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 50       |
# |    ep_rew_mean          | -50      |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 535      |
# |    iterations           | 17       |
# |    time_elapsed         | 1040     |
# |    total_timesteps      | 557056   |
# | train/                  |          |
# |    approx_kl            | 0.022783 |
# |    clip_fraction        | 0.203    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.67    |
# |    explained_variance   | 0.928    |
# |    learning_rate        | 0.00015  |
# |    loss                 | -0.08    |
# |    n_updates            | 320      |
# |    policy_gradient_loss | -0.0324  |
# |    std                  | 0.821    |
# |    value_loss           | 0.00387  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 18          |
# |    time_elapsed         | 1099        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.022367414 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0819     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0349     |
# |    std                  | 0.809       |
# |    value_loss           | 0.00358     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 19          |
# |    time_elapsed         | 1156        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.025965255 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0815     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 0.795       |
# |    value_loss           | 0.00382     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 20          |
# |    time_elapsed         | 1218        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.023080224 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0795     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0329     |
# |    std                  | 0.786       |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 21          |
# |    time_elapsed         | 1278        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.024159735 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0713     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.777       |
# |    value_loss           | 0.00509     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 22          |
# |    time_elapsed         | 1336        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.026769266 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0757     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0311     |
# |    std                  | 0.768       |
# |    value_loss           | 0.0054      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 23          |
# |    time_elapsed         | 1398        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.027250377 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0781     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.76        |
# |    value_loss           | 0.00598     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 24          |
# |    time_elapsed         | 1460        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.028406242 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0785     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 0.75        |
# |    value_loss           | 0.00476     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 25          |
# |    time_elapsed         | 1521        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.026564557 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0798     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.743       |
# |    value_loss           | 0.00523     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 539        |
# |    iterations           | 26         |
# |    time_elapsed         | 1580       |
# |    total_timesteps      | 851968     |
# | train/                  |            |
# |    approx_kl            | 0.02704703 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.33      |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0719    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0293    |
# |    std                  | 0.736      |
# |    value_loss           | 0.00707    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 539        |
# |    iterations           | 27         |
# |    time_elapsed         | 1638       |
# |    total_timesteps      | 884736     |
# | train/                  |            |
# |    approx_kl            | 0.02806725 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.08      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0327    |
# |    std                  | 0.729      |
# |    value_loss           | 0.00564    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 28          |
# |    time_elapsed         | 1701        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.028485667 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0773     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0329     |
# |    std                  | 0.721       |
# |    value_loss           | 0.00692     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 29          |
# |    time_elapsed         | 1761        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.025879709 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0727     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.719       |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.7       |
# |    ep_rew_mean          | -49.7      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 539        |
# |    iterations           | 30         |
# |    time_elapsed         | 1821       |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.02702523 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0756    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0306    |
# |    std                  | 0.712      |
# |    value_loss           | 0.0104     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 31          |
# |    time_elapsed         | 1884        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.029580269 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0733     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0298     |
# |    std                  | 0.707       |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.3       |
# |    ep_rew_mean          | -49.3      |
# |    success_rate         | 0.02       |
# | time/                   |            |
# |    fps                  | 538        |
# |    iterations           | 32         |
# |    time_elapsed         | 1946       |
# |    total_timesteps      | 1048576    |
# | train/                  |            |
# |    approx_kl            | 0.02742529 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0807    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0358    |
# |    std                  | 0.701      |
# |    value_loss           | 0.00971    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 33          |
# |    time_elapsed         | 2006        |
# |    total_timesteps      | 1081344     |
# | train/                  |             |
# |    approx_kl            | 0.028497308 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0747     |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.693       |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 34          |
# |    time_elapsed         | 2066        |
# |    total_timesteps      | 1114112     |
# | train/                  |             |
# |    approx_kl            | 0.028094824 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0694     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.692       |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.7        |
# |    ep_rew_mean          | -49.7       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 35          |
# |    time_elapsed         | 2125        |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.029003523 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0744     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.686       |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.3        |
# |    ep_rew_mean          | -49.2       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 36          |
# |    time_elapsed         | 2187        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.029960126 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0797     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.68        |
# |    value_loss           | 0.0166      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 538        |
# |    iterations           | 37         |
# |    time_elapsed         | 2253       |
# |    total_timesteps      | 1212416    |
# | train/                  |            |
# |    approx_kl            | 0.03155235 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0724    |
# |    n_updates            | 720        |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 0.674      |
# |    value_loss           | 0.025      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 38          |
# |    time_elapsed         | 2320        |
# |    total_timesteps      | 1245184     |
# | train/                  |             |
# |    approx_kl            | 0.032037254 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0822     |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0358     |
# |    std                  | 0.67        |
# |    value_loss           | 0.0189      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.6       |
# |    ep_rew_mean          | -49.6      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 534        |
# |    iterations           | 39         |
# |    time_elapsed         | 2390       |
# |    total_timesteps      | 1277952    |
# | train/                  |            |
# |    approx_kl            | 0.03372089 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0773    |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.0356    |
# |    std                  | 0.666      |
# |    value_loss           | 0.0179     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.6       |
# |    ep_rew_mean          | -49.6      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 532        |
# |    iterations           | 40         |
# |    time_elapsed         | 2462       |
# |    total_timesteps      | 1310720    |
# | train/                  |            |
# |    approx_kl            | 0.03344077 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0588    |
# |    n_updates            | 780        |
# |    policy_gradient_loss | -0.031     |
# |    std                  | 0.666      |
# |    value_loss           | 0.0271     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 530        |
# |    iterations           | 41         |
# |    time_elapsed         | 2532       |
# |    total_timesteps      | 1343488    |
# | train/                  |            |
# |    approx_kl            | 0.03158238 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.97      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0631    |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.0327    |
# |    std                  | 0.658      |
# |    value_loss           | 0.0291     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.3       |
# |    ep_rew_mean          | -49.3      |
# |    success_rate         | 0.02       |
# | time/                   |            |
# |    fps                  | 529        |
# |    iterations           | 42         |
# |    time_elapsed         | 2598       |
# |    total_timesteps      | 1376256    |
# | train/                  |            |
# |    approx_kl            | 0.03240131 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.95      |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0708    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0336    |
# |    std                  | 0.654      |
# |    value_loss           | 0.0227     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 43          |
# |    time_elapsed         | 2673        |
# |    total_timesteps      | 1409024     |
# | train/                  |             |
# |    approx_kl            | 0.032811075 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0688     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.65        |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 525        |
# |    iterations           | 44         |
# |    time_elapsed         | 2745       |
# |    total_timesteps      | 1441792    |
# | train/                  |            |
# |    approx_kl            | 0.03209638 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.91      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0801    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0337    |
# |    std                  | 0.647      |
# |    value_loss           | 0.0258     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -50         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 45          |
# |    time_elapsed         | 2810        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.036212977 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0669     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0357     |
# |    std                  | 0.643       |
# |    value_loss           | 0.0233      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.3        |
# |    ep_rew_mean          | -49.3       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 46          |
# |    time_elapsed         | 2876        |
# |    total_timesteps      | 1507328     |
# | train/                  |             |
# |    approx_kl            | 0.035784673 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0771     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0379     |
# |    std                  | 0.638       |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# |    success_rate         | 0.03        |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 47          |
# |    time_elapsed         | 2945        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.031772856 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0736     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 0.636       |
# |    value_loss           | 0.0272      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 48          |
# |    time_elapsed         | 3011        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.031092338 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.067      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0337     |
# |    std                  | 0.635       |
# |    value_loss           | 0.0253      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.3        |
# |    ep_rew_mean          | -48.3       |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 49          |
# |    time_elapsed         | 3079        |
# |    total_timesteps      | 1605632     |
# | train/                  |             |
# |    approx_kl            | 0.034700073 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0702     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.633       |
# |    value_loss           | 0.027       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.6       |
# |    ep_rew_mean          | -48.5      |
# |    success_rate         | 0.04       |
# | time/                   |            |
# |    fps                  | 519        |
# |    iterations           | 50         |
# |    time_elapsed         | 3150       |
# |    total_timesteps      | 1638400    |
# | train/                  |            |
# |    approx_kl            | 0.03285607 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.068     |
# |    n_updates            | 980        |
# |    policy_gradient_loss | -0.0347    |
# |    std                  | 0.628      |
# |    value_loss           | 0.0198     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -50        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 518        |
# |    iterations           | 51         |
# |    time_elapsed         | 3224       |
# |    total_timesteps      | 1671168    |
# | train/                  |            |
# |    approx_kl            | 0.03485364 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.81      |
# ...
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41         |
# |    ep_rew_mean          | -40.7      |
# |    success_rate         | 0.35       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 290        |
# |    time_elapsed         | 20394      |
# |    total_timesteps      | 9502720    |
# | train/                  |            |
# |    approx_kl            | 0.09676402 |
# |    clip_fraction        | 0.493      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00715   |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0372    |
# |    n_updates            | 5780       |
# |    policy_gradient_loss | -0.0375    |
# |    std                  | 0.277      |
# |    value_loss           | 0.0758     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39         |
# |    ep_rew_mean          | -38.6      |
# |    success_rate         | 0.42       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 291        |
# |    time_elapsed         | 20472      |
# |    total_timesteps      | 9535488    |
# | train/                  |            |
# |    approx_kl            | 0.11215968 |
# |    clip_fraction        | 0.511      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.00817    |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0287    |
# |    n_updates            | 5800       |
# |    policy_gradient_loss | -0.0338    |
# |    std                  | 0.276      |
# |    value_loss           | 0.0782     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 44.1      |
# |    ep_rew_mean          | -43.9     |
# |    success_rate         | 0.26      |
# | time/                   |           |
# |    fps                  | 465       |
# |    iterations           | 292       |
# |    time_elapsed         | 20551     |
# |    total_timesteps      | 9568256   |
# | train/                  |           |
# |    approx_kl            | 0.1521675 |
# |    clip_fraction        | 0.537     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.0203    |
# |    explained_variance   | 0.86      |
# |    learning_rate        | 0.00015   |
# |    loss                 | -0.0306   |
# |    n_updates            | 5820      |
# |    policy_gradient_loss | -0.034    |
# |    std                  | 0.274     |
# |    value_loss           | 0.0796    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.6       |
# |    ep_rew_mean          | -39.2      |
# |    success_rate         | 0.39       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 293        |
# |    time_elapsed         | 20625      |
# |    total_timesteps      | 9601024    |
# | train/                  |            |
# |    approx_kl            | 0.12775894 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0328     |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0249    |
# |    n_updates            | 5840       |
# |    policy_gradient_loss | -0.0367    |
# |    std                  | 0.274      |
# |    value_loss           | 0.0963     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.2       |
# |    ep_rew_mean          | -40.9      |
# |    success_rate         | 0.33       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 294        |
# |    time_elapsed         | 20697      |
# |    total_timesteps      | 9633792    |
# | train/                  |            |
# |    approx_kl            | 0.13173269 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0396     |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0302    |
# |    n_updates            | 5860       |
# |    policy_gradient_loss | -0.0349    |
# |    std                  | 0.273      |
# |    value_loss           | 0.0754     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.3       |
# |    ep_rew_mean          | -40        |
# |    success_rate         | 0.35       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 295        |
# |    time_elapsed         | 20767      |
# |    total_timesteps      | 9666560    |
# | train/                  |            |
# |    approx_kl            | 0.11852935 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0552     |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.036     |
# |    n_updates            | 5880       |
# |    policy_gradient_loss | -0.039     |
# |    std                  | 0.271      |
# |    value_loss           | 0.0765     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.4       |
# |    ep_rew_mean          | -41.1      |
# |    success_rate         | 0.32       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 296        |
# |    time_elapsed         | 20839      |
# |    total_timesteps      | 9699328    |
# | train/                  |            |
# |    approx_kl            | 0.15282841 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0747     |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0293    |
# |    n_updates            | 5900       |
# |    policy_gradient_loss | -0.0315    |
# |    std                  | 0.27       |
# |    value_loss           | 0.0682     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.5       |
# |    ep_rew_mean          | -39.1      |
# |    success_rate         | 0.39       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 297        |
# |    time_elapsed         | 20914      |
# |    total_timesteps      | 9732096    |
# | train/                  |            |
# |    approx_kl            | 0.12901568 |
# |    clip_fraction        | 0.51       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0873     |
# |    explained_variance   | 0.875      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0319    |
# |    n_updates            | 5920       |
# |    policy_gradient_loss | -0.0366    |
# |    std                  | 0.269      |
# |    value_loss           | 0.0763     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.7       |
# |    ep_rew_mean          | -40.4      |
# |    success_rate         | 0.33       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 298        |
# |    time_elapsed         | 20986      |
# |    total_timesteps      | 9764864    |
# | train/                  |            |
# |    approx_kl            | 0.11818069 |
# |    clip_fraction        | 0.523      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.104      |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0359    |
# |    n_updates            | 5940       |
# |    policy_gradient_loss | -0.038     |
# |    std                  | 0.267      |
# |    value_loss           | 0.084      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.4       |
# |    ep_rew_mean          | -43.1      |
# |    success_rate         | 0.26       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 299        |
# |    time_elapsed         | 21057      |
# |    total_timesteps      | 9797632    |
# | train/                  |            |
# |    approx_kl            | 0.13163835 |
# |    clip_fraction        | 0.513      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.126      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0281    |
# |    n_updates            | 5960       |
# |    policy_gradient_loss | -0.0382    |
# |    std                  | 0.265      |
# |    value_loss           | 0.0775     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.1       |
# |    ep_rew_mean          | -39.7      |
# |    success_rate         | 0.37       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 300        |
# |    time_elapsed         | 21131      |
# |    total_timesteps      | 9830400    |
# | train/                  |            |
# |    approx_kl            | 0.13436195 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.142      |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0387    |
# |    n_updates            | 5980       |
# |    policy_gradient_loss | -0.0359    |
# |    std                  | 0.264      |
# |    value_loss           | 0.0666     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 42.2      |
# |    ep_rew_mean          | -41.9     |
# |    success_rate         | 0.3       |
# | time/                   |           |
# |    fps                  | 465       |
# |    iterations           | 301       |
# |    time_elapsed         | 21203     |
# |    total_timesteps      | 9863168   |
# | train/                  |           |
# |    approx_kl            | 0.1215688 |
# |    clip_fraction        | 0.517     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.157     |
# |    explained_variance   | 0.889     |
# |    learning_rate        | 0.00015   |
# |    loss                 | -0.0363   |
# |    n_updates            | 6000      |
# |    policy_gradient_loss | -0.0346   |
# |    std                  | 0.262     |
# |    value_loss           | 0.0679    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.8       |
# |    ep_rew_mean          | -40.5      |
# |    success_rate         | 0.36       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 302        |
# |    time_elapsed         | 21273      |
# |    total_timesteps      | 9895936    |
# | train/                  |            |
# |    approx_kl            | 0.13491234 |
# |    clip_fraction        | 0.516      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.175      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0376    |
# |    n_updates            | 6020       |
# |    policy_gradient_loss | -0.0358    |
# |    std                  | 0.261      |
# |    value_loss           | 0.0707     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.7       |
# |    ep_rew_mean          | -39.4      |
# |    success_rate         | 0.38       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 303        |
# |    time_elapsed         | 21344      |
# |    total_timesteps      | 9928704    |
# | train/                  |            |
# |    approx_kl            | 0.13509856 |
# |    clip_fraction        | 0.526      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.185      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0312    |
# |    n_updates            | 6040       |
# |    policy_gradient_loss | -0.0326    |
# |    std                  | 0.26       |
# |    value_loss           | 0.0816     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.8       |
# |    ep_rew_mean          | -40.5      |
# |    success_rate         | 0.35       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 304        |
# |    time_elapsed         | 21417      |
# |    total_timesteps      | 9961472    |
# | train/                  |            |
# |    approx_kl            | 0.12841865 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.187      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0251    |
# |    n_updates            | 6060       |
# |    policy_gradient_loss | -0.036     |
# |    std                  | 0.261      |
# |    value_loss           | 0.0761     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.8       |
# |    ep_rew_mean          | -41.5      |
# |    success_rate         | 0.32       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 305        |
# |    time_elapsed         | 21487      |
# |    total_timesteps      | 9994240    |
# | train/                  |            |
# |    approx_kl            | 0.13540833 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.193      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0356    |
# |    n_updates            | 6080       |
# |    policy_gradient_loss | -0.037     |
# |    std                  | 0.26       |
# |    value_loss           | 0.0818     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.3       |
# |    ep_rew_mean          | -43.1      |
# |    success_rate         | 0.25       |
# | time/                   |            |
# |    fps                  | 465        |
# |    iterations           | 306        |
# |    time_elapsed         | 21556      |
# |    total_timesteps      | 10027008   |
# | train/                  |            |
# |    approx_kl            | 0.13637587 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.203      |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.0387    |
# |    n_updates            | 6100       |
# |    policy_gradient_loss | -0.0355    |
# |    std                  | 0.259      |
# |    value_loss           | 0.0818     |
# ----------------------------------------

# %%
model_ppo.save("ppo-PandaSlide")
env.save("PandaSlide_vec_normalize_ppo.pkl")

# %%
eval_env = DummyVecEnv([lambda: gym.make(env_id)])
eval_env = VecNormalize.load("PandaSlide_vec_normalize_ppo.pkl", eval_env)

# We need to override the render_mode
eval_env.render_mode = "rgb_array"

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = PPO.load("ppo-PandaSlide")

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# /home/tomek/pytorch_learning/venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = -42.60 +/- 12.33

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from huggingface_sb3 import package_to_hub

package_to_hub(
    model=model,
    model_name=f"ppo-{env_id}",
    model_architecture="PPO",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"Hevagog/ppo-{env_id}",
    commit_message="Initial Push",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /home/tomek/pytorch_learning/venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmp13op90yz/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp13op90yz/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp13op90yz/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp13op90yz/-step-0-to-step-1000.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmp13op90yz/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:40.04, start: 0.000000, bitrate: 167 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x480, 164 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56452a5b3ac0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56452a5b3ac0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x56452a5b3ac0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmpfvbphull/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 720x480, q=2-31, 25 fps, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1001 fps=0.0 q=-1.0 Lsize=     796kB time=00:00:39.92 bitrate= 163.3kbits/s speed=50.4x
# video:784kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.585222%
# [libx264 @ 0x56452a5b3ac0] frame I:5     Avg QP:18.10  size:  7897
# [libx264 @ 0x56452a5b3ac0] frame P:273   Avg QP:24.58  size:  1224
# [libx264 @ 0x56452a5b3ac0] frame B:723   Avg QP:29.05  size:   592
# [libx264 @ 0x56452a5b3ac0] consecutive B-frames:  1.6%  4.2%  6.3% 87.9%
# [libx264 @ 0x56452a5b3ac0] mb I  I16..4: 20.5% 60.9% 18.6%
# [libx264 @ 0x56452a5b3ac0] mb P  I16..4:  0.2%  0.7%  0.8%  P16..4:  2.5%  1.7%  1.1%  0.0%  0.0%    skip:93.0%
# [libx264 @ 0x56452a5b3ac0] mb B  I16..4:  0.0%  0.1%  0.1%  B16..8:  3.7%  1.8%  0.7%  direct: 0.2%  skip:93.4%  L0:49.5% L1:46.6% BI: 3.9%
# [libx264 @ 0x56452a5b3ac0] 8x8 transform intra:52.3% inter:7.7%
# [libx264 @ 0x56452a5b3ac0] coded y,uvDC,uvAC intra: 22.1% 3.9% 2.3% inter: 1.0% 0.0% 0.0%
# [libx264 @ 0x56452a5b3ac0] i16 v,h,dc,p: 69% 11% 19%  1%
# [libx264 @ 0x56452a5b3ac0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 15% 46%  0%  0%  0%  0%  0%  1%
# [libx264 @ 0x56452a5b3ac0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 18% 27%  3%  5%  5%  6%  3%  5%
# [libx264 @ 0x56452a5b3ac0] i8c dc,h,v,p: 94%  3%  3%  0%
# [libx264 @ 0x56452a5b3ac0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56452a5b3ac0] ref P L0: 58.2%  5.0% 22.5% 14.2%
# [libx264 @ 0x56452a5b3ac0] ref B L0: 74.4% 20.3%  5.3%
# [libx264 @ 0x56452a5b3ac0] ref B L1: 93.2%  6.8%
# [libx264 @ 0x56452a5b3ac0] kb/s:160.17
# ℹ Pushing repo Hevagog/ppo-PandaSlide-v3 to the Hugging Face Hub
# policy.pth:   0%|          | 0.00/4.32M [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# ppo-PandaSlide-v3.zip:   0%|          | 0.00/13.0M [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/8.64M [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/3.07k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Hevagog/ppo-PandaSlide-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Hevagog/ppo-PandaSlide-v3/commit/75d3823878fb685100db8ce628e7309a5839b9b4', commit_message='Initial Push', commit_description='', oid='75d3823878fb685100db8ce628e7309a5839b9b4', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ---
